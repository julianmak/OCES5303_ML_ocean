# %% [markdown]
# *03 Aug 2026, Julian Mak (whatever with copyright, do what you want with this)
#
# ### As part of material for OCES 5303 "AI and Machine Learning in Ocean Science" delivered at HKUST
#
# For the latest version of the material, go to the public facing [GitHub](https://github.com/julianmak/OCES5303_ML_ocean) page.
#
# ### General spiel about assessment
#
# ***Your hand in should be in the form of a pdf file, and no other form of hand-ins will be accepted***. Hand these in through Canvas in the usual way.
#
# You are graded on the following attributes:
#
# 1) **scientific content** (40%)
#
# 2) **writing, presentation and referencing** (30%)
#
# 3) **defense in the interview style exam** (30%; this part is different to the smaller assignments)
#
# 4) **orginality** (10%; analysis beyond scope of course, use of memes and puns, reproducible code that runs fresh; surprise me)
#
# a) ***Late assignments get a penalty of 1% of full marks per minute*** (so don't bother handing in anything after 2 hours). We will still mark it and give feedback, but you just don't get the credit. Excuses could be entertained but you will need sufficient evidence to back this up (e.g. your internet went down in the area and you have some pictorial/written demosntration for this).
#
# b) For this one ***we DON'T want the Jupyter notebook***!!! Give us a pdf.
#
# c) ***There is a penalty for excessive length***. If the result is more than 20 pages that is too long, which will hit category 2 above (because it's too long).
#
# d) ***Originality (category 4 above) is extra and treat it as such***. Cutting-edge things done poorly would still be evaluated as "poor"; you may get some marks for category 4, but you could lose marks in all other parts.
#
# If you upload your assignment onto a GitHub repository and give us the link, with the appropriate things built in so that we can open it in Colab, then you get extra credit because of making the things openly reproducible and helping us somewhat. Again, it needs to be done "well", not just "done"; the latter gives you no credit by itself.
#
# e) ***Plagiarism***: By all means consult each other and/or work together, but the files you hand in should be done and written up separately. **The default for anyone accused with plagiarism is ZERO on the assignment**, and depending on whether you decide to contest and the result of the appeal, possibly lead to an official note of plagiarism on your transcript (arguing has a risk associated with it but it is part of the system).
#
# A few things count as plagiarism:
#
# **Copying between students, and the default is that ALL parties involved get zero for the assignment**, regardless of whether the side can demonstrate they were copied from (extra incentive to keep the writing separate).
#
# **Copying text without citation is plagiarism**. Use quotation marks and give reference if you are directly lifting text, but don't do this too often (and will result in text looking cluttered, and not getting full credit for the *presentation* aspect).
#
# **Code is a slightly more grey area**, but I will just say no one has ever really been punished for being cautious and generous with citations, but make sure you present it well (e.g. overburdening text with citations will make the presentation ugly, and will not get full credit for the *presentation* aspect say).
#
# If we are making a penalty on plagiarism it probably means we think we have a sufficiently strong case that is unlikely arguable (I don't fight battles I know I will lose).

# %% [markdown]
# ---------------------------
# # Extend project (25% of total course grade)
#
# For this you should use your own data and deploy your choice of machine learning things to investigate your chocie of data; you can do any number of tools (and you may want to do at least two), but one of these have to be a neural network of some description.
#
# For this one we want a submission as an qualifying exam report document (or an article document if you like) in pdf format. We don't need to see the coding details (you can show it if you think it helps the narrative). You need to describe what the data is, what is the scientific question you want to address, the details of the machine learning algorithm you deploy and why that is a suitable choice, the choice of model parameters/architecture and robustness to those, a critique/evaluation of the results and a conclusion. You would also need to defend your choices in the interview style exam (cf. qualifying exam Q&A session).
#
# ***Note that it doesn't need to work*** ("work" in whatever sense you want it to mean). The interest here is not in getting something that works, but to demonstrate you can deploy things, speculate why it doesn't work, identify how you might make it work, and talk about those. There is no one way that is "right" (just like there is no single way of something being a "good" article, although there are usually commonalities between "good" things). I would recommend doing two flavours of neural networks, doing one single task (classification or regression), and being reasonably thorough with model comparison, sensitivity on hyper-parameter exploration, model validation and so forth.
#
# <u>Note</u>: For the present purpose, you are allowed to cite Wikipedia, but you probably also want to not have Wikipedia be your only source.
#
# ***You should name your hand-in file as something like "project_oces5303_STUDENTID.pdf" when you hand the notebook in through Canvas***.
#
# ---
